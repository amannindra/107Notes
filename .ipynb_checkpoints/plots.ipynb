# %%
from datascience import Table
import numpy as np
import matplotlib.pyplot as plot
plot.style.use("fivethirtyeight")
# %matplotlib inline

# %%
actorsread = Table.read_table('actors.csv')

# %%
actorsread.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Actor</th> <th>Total Gross</th> <th>Number of Movies</th> <th>Average per Movie</th> <th>#1 Movie</th> <th>Gross</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Harrison Ford     </td> <td>4871.7     </td> <td>41              </td> <td>118.8            </td> <td>Star Wars: The Force Awakens</td> <td>936.7</td>
#         </tr>
#         <tr>
#             <td>Samuel L. Jackson </td> <td>4772.8     </td> <td>69              </td> <td>69.2             </td> <td>The Avengers                </td> <td>623.4</td>
#         </tr>
#         <tr>
#             <td>Morgan Freeman    </td> <td>4468.3     </td> <td>61              </td> <td>73.3             </td> <td>The Dark Knight             </td> <td>534.9</td>
#         </tr>
#         <tr>
# ...

# %%
actorsread.select("Actor", "Total Gross")
# Out:
# Actor              | Total Gross
# Harrison Ford      | 4871.7
# Samuel L. Jackson  | 4772.8
# Morgan Freeman     | 4468.3
# Tom Hanks          | 4340.8
# Robert Downey, Jr. | 3947.3
# Eddie Murphy       | 3810.4
# Tom Cruise         | 3587.2
# Johnny Depp        | 3368.6
# Michael Caine      | 3351.5
# Scarlett Johansson | 3341.2
# ... (40 rows omitted)

# %%
Age = Table.read_table("nc-est2019-agesex-res.csv")

# %%
Age.select("SEX","AGE").show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>SEX</th> <th>AGE</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>0   </td> <td>0   </td>
#         </tr>
#         <tr>
#             <td>0   </td> <td>1   </td>
#         </tr>
#         <tr>
#             <td>0   </td> <td>2   </td>
#         </tr>
#         <tr>
#             <td>0   </td> <td>3   </td>
#         </tr>
#         <tr>
#             <td>0   </td> <td>4   </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (301 rows omitted)</p>

# %%
Age.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>SEX</th> <th>AGE</th> <th>CENSUS2010POP</th> <th>ESTIMATESBASE2010</th> <th>POPESTIMATE2010</th> <th>POPESTIMATE2011</th> <th>POPESTIMATE2012</th> <th>POPESTIMATE2013</th> <th>POPESTIMATE2014</th> <th>POPESTIMATE2015</th> <th>POPESTIMATE2016</th> <th>POPESTIMATE2017</th> <th>POPESTIMATE2018</th> <th>POPESTIMATE2019</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>0   </td> <td>0   </td> <td>3944153      </td> <td>3944160          </td> <td>3951430        </td> <td>3963092        </td> <td>3926570        </td> <td>3931258        </td> <td>3954787        </td> <td>3983981        </td> <td>3954773        </td> <td>3893990        </td> <td>3815343        </td> <td>3783052        </td>
#         </tr>
#         <tr>
# ...

# %%
simple = Age.relabeled(4,"2010").relabeled(5,"2011").relabeled(6,"2012").relabeled(7,"2013").relabeled(8,"2014").relabeled(9,"2015").relabeled(10,"2016")

# %%
simple.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>SEX</th> <th>AGE</th> <th>CENSUS2010POP</th> <th>ESTIMATESBASE2010</th> <th>2010</th> <th>2011</th> <th>2012</th> <th>2013</th> <th>2014</th> <th>2015</th> <th>2016</th> <th>POPESTIMATE2017</th> <th>POPESTIMATE2018</th> <th>POPESTIMATE2019</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>0   </td> <td>0   </td> <td>3944153      </td> <td>3944160          </td> <td>3951430</td> <td>3963092</td> <td>3926570</td> <td>3931258</td> <td>3954787</td> <td>3983981</td> <td>3954773</td> <td>3893990        </td> <td>3815343        </td> <td>3783052        </td>
#         </tr>
#         <tr>
#             <td>0   </td> <td>1   </td> <td>3978070      </td> <td>3978090          </td> <td>3957730</td> <td>3966225</td> <td>3977549</td> <td>3942698</td> <td>3948891</td> <td>3973133</td> <td>4002903</td> <td>3972711        </td> <td>3908830        </td> <td>3829599        </td>
# ...

# %%
simple = simple.relabeled(11,"2017").relabeled(12,"2018").relabeled(13,"2019")

# %%
no_999 = simple.where("AGE", are.below(99))

# %%
overall = no_999.where("SEX",0)

# %%
overall.plot("AGE","2019")

# %%
males = no_999.where("SEX",1)
males.show(10)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>SEX</th> <th>AGE</th> <th>CENSUS2010POP</th> <th>ESTIMATESBASE2010</th> <th>2010</th> <th>2011</th> <th>2012</th> <th>2013</th> <th>2014</th> <th>2015</th> <th>2016</th> <th>2017</th> <th>2018</th> <th>2019</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1   </td> <td>0   </td> <td>2014276      </td> <td>2014278          </td> <td>2018474</td> <td>2028430</td> <td>2007742</td> <td>2009723</td> <td>2024511</td> <td>2037646</td> <td>2021375</td> <td>1991761</td> <td>1951663</td> <td>1935117</td>
#         </tr>
#         <tr>
#             <td>1   </td> <td>1   </td> <td>2030853      </td> <td>2030861          </td> <td>2020235</td> <td>2025272</td> <td>2035213</td> <td>2015723</td> <td>2018511</td> <td>2033686</td> <td>2046917</td> <td>2030158</td> <td>1999022</td> <td>1958585</td>
#         </tr>
#         <tr>
# ...

# %%
males.plot("AGE", "2019")

# %%
Females = no_999.where("SEX",2)
Females.plot("AGE", "2019")

# %%
pop_2019 = Table().with_columns('AGE', males.column('AGE')).with_columns('MALES', males.column('2019')).with_columns('FEMALES', Females.column('2019'))

# %%
pop_2019.plot()

# %%
x = [5,8,10]
y= [12, 16,6]
x2= [6,9,11]
y2=[6,15,7]

# %%
plot.plot(x,y,'g',label='line one',linewidth=5)
plot.plot(x2,y2,'c',label='line two',linewidth=5)
plot.xlabel("X Axis")
plot.ylabel("Y Axis")
plot.legend()
plot.title('X Vs Y')
# Out:
# Text(0.5, 1.0, 'X Vs Y')

# %%
plot.bar([1,3,7,9],[5,2,7,8],label='Example one')
plot.bar([2,4,6,8,10],[8,6,2,5,6],label='Example two')
plot.legend()
plot.xlabel("Bar number")
plot.ylabel("Bar hieght")
plot.title("My plot")
plot.show()

# %%
x=['java','python','PHP','javascript','C#','C++']
y= [22.2,17.6,8.8,8,7.7,6.7]
plot.bar(x,y,label
